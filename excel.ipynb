# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("Sample - Superstore.csv", encoding="latin1")

# %% [markdown]
# | Column        | المعنى بالإنجليزي   | الشرح بالعربي                                                    |
# | ------------- | ------------------- | ---------------------------------------------------------------- |
# | Row ID        | Unique Row Number   | رقم فريد لكل صف في الداتا                                        |
# | Order ID      | Order Identifier    | رقم الطلب الذي قام به العميل                                     |
# | Order Date    | Date of Order       | تاريخ عمل الطلب                                                  |
# | Ship Date     | Shipping Date       | تاريخ شحن الطلب للعميل                                           |
# | Ship Mode     | Shipping Method     | طريقة الشحن (Standard – First Class – Same Day)                  |
# | Customer ID   | Customer Identifier | رقم تعريف العميل                                                 |
# | Customer Name | Customer Name       | اسم العميل                                                       |
# | Segment       | Customer Segment    | نوع العميل (Consumer – Corporate – Home Office)                  |
# | Country       | Country             | الدولة                                                           |
# | City          | City                | المدينة                                                          |
# | State         | State               | المحافظة أو الولاية                                              |
# | Postal Code   | Postal Code         | الرمز البريدي                                                    |
# | Region        | Region              | المنطقة الجغرافية (East – West – Central – South)                |
# | Product ID    | Product Identifier  | رقم تعريف المنتج                                                 |
# | Category      | Product Category    | الفئة الرئيسية للمنتج (Furniture – Office Supplies – Technology) |
# | Sub-Category  | Product Subcategory | الفئة الفرعية للمنتج (Chairs – Phones – Storage...)              |
# | Product Name  | Product Name        | اسم المنتج                                                       |
# | Sales         | Sales Amount        | قيمة المبيعات بالدولار                                           |
# | Quantity      | Quantity Sold       | عدد القطع المباعة                                                |
# | Discount      | Discount Rate       | نسبة الخصم على المنتج                                            |
# | Profit        | Profit Amount       | الربح الناتج من بيع المنتج                                       |

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.drop(columns=["Row ID"], inplace=True)
df.reset_index(inplace=True, drop=True)

# %%
df.isna().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df['AVG Shipping Time'] = (df['Ship Date'] - df['Order Date']).dt.days
df.reset_index(inplace=True, drop=True)

# %%
df.describe()
# Out:
#                           Order Date                      Ship Date  \
# count                           9994                           9994
# mean   2016-04-30 00:07:12.259355648  2016-05-03 23:06:58.571142912
# min              2014-01-03 00:00:00            2014-01-07 00:00:00
# 25%              2015-05-23 00:00:00            2015-05-27 00:00:00
# 50%              2016-06-26 00:00:00            2016-06-29 00:00:00
# 75%              2017-05-14 00:00:00            2017-05-18 00:00:00
# max              2017-12-30 00:00:00            2018-01-05 00:00:00
# std                              NaN                            NaN
#
#         Postal Code         Sales     Quantity     Discount       Profit  \
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# ...

# %%
IQR= 209.940000-17.280000
upper= 209.940000 + 1.5*IQR
lower= 17.280000 - 1.5*IQR

# %%
upper
# Out:
# 498.93

# %%
df[(df['Sales']>=upper) & (df['Sub-Category']=='Machines')].head(30)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 165   CA-2014-139892 2014-09-08 2014-09-12  Standard Class    BM-11140
# 215   CA-2015-146262 2015-01-02 2015-01-09  Standard Class    VW-21775
# 262   US-2014-106992 2014-09-19 2014-09-21    Second Class    SB-20290
# 263   US-2014-106992 2014-09-19 2014-09-21    Second Class    SB-20290
# 318   CA-2014-164973 2014-11-04 2014-11-09  Standard Class    NM-18445
# 436   CA-2016-147375 2016-06-12 2016-06-14    Second Class    PO-19180
# 683   US-2017-168116 2017-11-04 2017-11-04        Same Day    GT-14635
# 977   CA-2017-159366 2017-01-07 2017-01-10     First Class    BW-11110
# 1022  CA-2015-124450 2015-04-27 2015-05-03  Standard Class    GT-14710
# 1085  US-2016-143819 2016-03-01 2016-03-05  Standard Class    KD-16270
# 1144  CA-2014-146969 2014-09-29 2014-10-03  Standard Class    AP-10915
# 1340  CA-2017-113481 2017-01-02 2017-01-04     First Class    AS-10045
# ...

# %%
df[df['Sales']==df['Sales'].max()]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2697  CA-2014-145317 2014-03-18 2014-03-23  Standard Class    SM-20320
#
#      Customer Name      Segment        Country          City    State  ...  \
# 2697   Sean Miller  Home Office  United States  Jacksonville  Florida  ...
#
#       Region       Product ID    Category Sub-Category  \
# 2697   South  TEC-MA-10002412  Technology     Machines
#
#                                            Product Name     Sales  Quantity  \
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.48         6
#
#       Discount     Profit  AVG Shipping Time
# 2697       0.5 -1811.0784                  5
#
# [1 rows x 21 columns]

# %%
df[df['Sub-Category']=='Machines']['Product Name'].nunique()
# Out:
# 63

# %%
df['year_of_order'] = df['Order Date'].dt.year
df['month_of_order'] = df['Order Date'].dt.month
df['day_of_order'] = df['Order Date'].dt.day

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    ...  Sub-Category                                       Product Name  \
# ...

# %%
total_salary = df['Sales'].sum()
print("Total Sales:", total_salary)
total_profit = df['Profit'].sum()
print("Total Profit:", total_profit)
avg_discount = df['Discount'].mean()
print("Average Discount:", avg_discount)
total_customers = df['Customer ID'].nunique()
print("Total Customers:", total_customers)
total_orderings = df['Order ID'].nunique()
print("Total Orderings:", total_orderings)
# Out:
# Total Sales: 2297200.8603
# Total Profit: 286397.0217
# Average Discount: 0.1562027216329798
# Total Customers: 793
# Total Orderings: 5009

# %%
max_discount = df['Discount'].max()
print("Maximum Discount:", max_discount)
# Out:
# Maximum Discount: 0.8

# %%
df[df['Discount']>=0.30]['Profit'].sum()
# Out:
# np.float64(-135376.056)

# %%
df[df['Discount']<=0.40]['Profit'].sum()
# Out:
# np.float64(385955.61220000003)

# %%
df[df['Discount']==0.30]['Profit'].sum()
# Out:
# np.float64(-10369.277399999999)

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    ...  Sub-Category                                       Product Name  \
# ...

# %%
total_salary_of_year = df.pivot_table(values='Profit', index='year_of_order',columns='month_of_order', aggfunc='sum')
#total_salary_of_year.sort_values(by='Profit', ascending=False)
total_salary_of_year
# Out:
# month_of_order         1          2           3          4          5   \
# year_of_order
# 2014            2450.1907   862.3084    498.7299  3488.8352  2738.7096
# 2015           -3281.0070  2813.8508   9732.0978  4187.4962  4667.8690
# 2016            2824.8233  5004.5795   3611.9680  2977.8149  8662.1464
# 2017            7140.4391  1613.8720  14751.8915   933.2900  6342.5828
#
# month_of_order         6          7          8           9           10  \
# year_of_order
# 2014            4976.5244  -841.4826  5318.1050   8328.0994   3448.2573
# 2015            3335.5572  3288.6483  5355.8084   8209.1627   2817.3660
# 2016            4750.3781  4432.8779  2062.0693   9328.6576  16243.1425
# 2017            8223.3357  6952.6212  9040.9557  10991.5556   9275.2755
#
# month_of_order          11          12
# year_of_order
# 2014             9292.1269   8983.5699
# 2015            12474.7884   8016.9659
# 2016             4011.4075  17885.3093
# 2017             9690.1037   8483.3468

# %%
total_profit_of_year = df.pivot_table(values='Profit', index='year_of_order', aggfunc='sum')
total_profit_of_year.sort_values(by='Profit', ascending=False)
# Out:
#                    Profit
# year_of_order
# 2017           93439.2696
# 2016           81795.1743
# 2015           61618.6037
# 2014           49543.9741

# %%
total_sales_of_year = df.pivot_table(values='Sales', index='year_of_order', aggfunc='sum')
total_sales_of_year.sort_values(by='Sales', ascending=False)
# Out:
#                      Sales
# year_of_order
# 2017           733215.2552
# 2016           609205.5980
# 2014           484247.4981
# 2015           470532.5090

# %%
total_salary_of_month = df.pivot_table(values='Profit', index='month_of_order', aggfunc='sum')
total_salary_of_month.sort_values(by='Profit', ascending=False)
# Out:
#                     Profit
# month_of_order
# 12              43369.1919
# 9               36857.4753
# 11              35468.4265
# 10              31784.0413
# 3               28594.6872
# 5               22411.3078
# 8               21776.9384
# 6               21285.7954
# 7               13832.6648
# 4               11587.4363
# 2               10294.6107
# 1                9134.4461

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
Ship_Mode = df.pivot_table( index='Ship Mode',values='Profit', aggfunc='mean')
Ship_Mode.reset_index(inplace=True)
Ship_Mode.sort_values(by='Profit', ascending=False, inplace=True)
Ship_Mode
# Out:
#         Ship Mode     Profit
# 0     First Class  31.839948
# 2    Second Class  29.535545
# 1        Same Day  29.266591
# 3  Standard Class  27.494770

# %%
df[(df['Discount']>=0.30) & (df['year_of_order']==2017) ]['Profit'].sum()
# Out:
# np.float64(-47569.8998)

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    ...  Sub-Category                                       Product Name  \
# ...

# %%
df[df['Profit']==df['Profit'].max()]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 6826  CA-2016-118689 2016-10-02 2016-10-09  Standard Class    TC-20980
#
#      Customer Name    Segment        Country       City    State  ...  \
# 6826  Tamara Chand  Corporate  United States  Lafayette  Indiana  ...
#
#       Sub-Category                           Product Name     Sales Quantity  \
# 6826       Copiers  Canon imageCLASS 2200 Advanced Copier  17499.95        5
#
#      Discount    Profit  AVG Shipping Time  year_of_order  month_of_order  \
# 6826      0.0  8399.976                  7           2016              10
#
#       day_of_order
# 6826             2
#
# [1 rows x 24 columns]

# %%
df[df['Customer Name']=='Tamara Chand'].head()
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2072  CA-2016-129693 2016-11-26 2016-12-02  Standard Class    TC-20980
# 3185  CA-2014-123498 2014-11-07 2014-11-09     First Class    TC-20980
# 3186  CA-2014-123498 2014-11-07 2014-11-09     First Class    TC-20980
# 6825  CA-2016-118689 2016-10-02 2016-10-09  Standard Class    TC-20980
# 6826  CA-2016-118689 2016-10-02 2016-10-09  Standard Class    TC-20980
#
#      Customer Name    Segment        Country       City       State  ...  \
# 2072  Tamara Chand  Corporate  United States    Seattle  Washington  ...
# 3185  Tamara Chand  Corporate  United States    Houston       Texas  ...
# 3186  Tamara Chand  Corporate  United States    Houston       Texas  ...
# 6825  Tamara Chand  Corporate  United States  Lafayette     Indiana  ...
# 6826  Tamara Chand  Corporate  United States  Lafayette     Indiana  ...
#
#       Sub-Category                                       Product Name  \
# ...

# %%
Segment_of_profit = df.pivot_table( index='Segment',values='Profit', aggfunc=['sum'])
Segment_of_profit.reset_index(inplace=True)
Segment_of_profit
# Out:
#        Segment          sum
#                      Profit
# 0     Consumer  134119.2092
# 1    Corporate   91979.1340
# 2  Home Office   60298.6785

# %%
Segment_of_sales = df.pivot_table( index='Segment',values='Sales', aggfunc=['sum'])
Segment_of_sales.reset_index(inplace=True)
Segment_of_sales
# Out:
#        Segment           sum
#                        Sales
# 0     Consumer  1.161401e+06
# 1    Corporate  7.061464e+05
# 2  Home Office  4.296531e+05

# %%
City_of_profit = df.pivot_table( index='City',values='Profit', aggfunc='sum')
City_of_profit.reset_index(inplace=True)
City_of_profit.sort_values(by='Profit', ascending=False, inplace=True)
City_of_profit.head(5)
# Out:
#               City      Profit
# 329  New York City  62036.9837
# 266    Los Angeles  30440.7579
# 452        Seattle  29156.0967
# 438  San Francisco  17507.3854
# 123        Detroit  13181.7908

# %%
City_of_profit = df.pivot_table( index='City',values='Profit', aggfunc='sum')
City_of_profit.reset_index(inplace=True)
City_of_profit.sort_values(by='Profit', ascending=True, inplace=True)
City_of_profit.head(5)
# Out:
#              City      Profit
# 374  Philadelphia -13837.7674
# 207       Houston -10153.5485
# 434   San Antonio  -7299.0502
# 241     Lancaster  -7239.0684
# 80        Chicago  -6654.5688

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'AVG Shipping Time',
#        'year_of_order', 'month_of_order', 'day_of_order'],
#       dtype='object')

# %%
df['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
Region_of_profit = df.pivot_table( index='Region',values='Profit', aggfunc='sum')
Region_of_profit.reset_index(inplace=True)
Region_of_profit.sort_values(by='Profit', ascending=False, inplace=True)
Region_of_profit
# Out:
#     Region       Profit
# 3     West  108418.4489
# 1     East   91522.7800
# 2    South   46749.4303
# 0  Central   39706.3625

# %%
Sub_Category_of_sales = df.pivot_table( index='Sub-Category',values='Sales', aggfunc='sum')
Sub_Category_of_sales.reset_index(inplace=True)
Sub_Category_of_sales.sort_values(by='Sales', ascending=False, inplace=True)
Sub_Category_of_sales
# Out:
#    Sub-Category        Sales
# 13       Phones  330007.0540
# 5        Chairs  328449.1030
# 14      Storage  223843.6080
# 16       Tables  206965.5320
# 3       Binders  203412.7330
# 11     Machines  189238.6310
# 0   Accessories  167380.3180
# 6       Copiers  149528.0300
# 4     Bookcases  114879.9963
# 1    Appliances  107532.1610
# 9   Furnishings   91705.1640
# 12        Paper   78479.2060
# 15     Supplies   46673.5380
# 2           Art   27118.7920
# 7     Envelopes   16476.4020
# 10       Labels   12486.3120
# 8     Fasteners    3024.2800

# %%
Sub_Category_of_profit = df.pivot_table( index='Sub-Category',values='Profit', aggfunc='mean')
Sub_Category_of_profit.reset_index(inplace=True)
Sub_Category_of_profit.sort_values(by='Profit', ascending=False, inplace=True)
Sub_Category_of_profit
# Out:
#    Sub-Category      Profit
# 6       Copiers  817.909190
# 0   Accessories   54.111788
# 13       Phones   50.073938
# 5        Chairs   43.095894
# 1    Appliances   38.922758
# 11     Machines   29.432669
# 7     Envelopes   27.418019
# 14      Storage   25.152277
# 12        Paper   24.856620
# 3       Binders   19.843574
# 10       Labels   15.236962
# 9   Furnishings   13.645918
# 2           Art    8.200737
# 8     Fasteners    4.375660
# 15     Supplies   -6.258418
# 4     Bookcases  -15.230509
# 16       Tables  -55.565771

# %%
Sub_Category_of_minus_profit = df.pivot_table( index='Sub-Category',values='Profit', aggfunc='sum')
Sub_Category_of_minus_profit.reset_index(inplace=True)
Sub_Category_of_minus_profit.sort_values(by='Profit', ascending=True, inplace=True)
Sub_Category_of_minus_profit.head(3)
# Out:
#    Sub-Category      Profit
# 16       Tables -17725.4811
# 4     Bookcases  -3472.5560
# 15     Supplies  -1189.0995

# %%
Category_of_profit = df.pivot_table( index='Category',values='Profit', aggfunc='mean')
Category_of_profit.reset_index(inplace=True)
Category_of_profit.sort_values(by='Profit', ascending=False, inplace=True)
Category_of_profit
# Out:
#           Category     Profit
# 2       Technology  78.752002
# 1  Office Supplies  20.327050
# 0        Furniture   8.699327

# %%
df['Profit margin'] = df['Profit'] / df['Sales']*100

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    ...                                       Product Name     Sales Quantity  \
# ...

# %%
Category_of_profit_margin = df.pivot_table( index='Category',values='Profit margin', aggfunc='mean')
Category_of_profit_margin.reset_index(inplace=True)
Category_of_profit_margin.sort_values(by='Profit margin', ascending=False, inplace=True)
Category_of_profit_margin
# Out:
#           Category  Profit margin
# 2       Technology      15.613805
# 1  Office Supplies      13.803029
# 0        Furniture       3.878353

# %%
Sub_Category_of_profit_margin = df.pivot_table( index='Sub-Category',values='Profit margin', aggfunc='mean')
Sub_Category_of_profit_margin.reset_index(inplace=True)
Sub_Category_of_profit_margin.sort_values(by='Profit margin', ascending=False, inplace=True)
Sub_Category_of_profit_margin.head(10)
# Out:
#    Sub-Category  Profit margin
# 10       Labels      42.966346
# 12        Paper      42.560036
# 7     Envelopes      42.313976
# 6       Copiers      31.719363
# 8     Fasteners      29.917051
# 2           Art      25.164573
# 0   Accessories      21.820968
# 9   Furnishings      13.706635
# 13       Phones      11.922197
# 15     Supplies      11.203947
